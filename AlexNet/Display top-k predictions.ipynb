# %% [markdown]
# ### Display top-k predictions

# %%
import numpy as np
import alexnet

# %%
network = alexnet.Alexnet()
network.load_data(sample_fraction=0.01)
network.create_generator(batch_size=32)
network.build_model()
#network.train(dataset_iterations=5)
# Out:
# Physical devices cannot be modified after being initialized
# Loading input dataset
# A fraction of 0.01 was selected from the total data
# Number of examples in the Train dataset is 12000 and in the Validation dataset is 1500
# Creating the generators
# WARNING:tensorflow:From /home/gpachitariu/git/ml-practice/AlexNet/alexnet.py:107: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.
# WARNING:tensorflow:From /home/gpachitariu/git/ml-practice/AlexNet/alexnet.py:107: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.

# %%
import utils
utils.display_images_with_predictions(network.train_augmented_gen, network)

# %%
# Load best version
trained_model = alexnet.Alexnet.load_model('trained_models/20200510-19:18:23')

# %%
utils.display_images_with_predictions(network.train_augmented_gen, network)

# %%
trained_model.predict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-47cbbdf66500> in <module>
# ----> 1 trained_model.predict()
#
# AttributeError: '_UserObject' object has no attribute 'predict'

# %%
layer_1_filter = network.model.get_weights()[0]
print("nan" + str(np.count_nonzero(np.isnan(layer_1_filter))))
print("non-nan" + str(np.count_nonzero(~np.isnan(layer_1_filter))))
# Out:
# nan0
# non-nan34848
