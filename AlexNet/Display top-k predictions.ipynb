# %% [markdown]
# ### Display top-k predictions

# %%
import numpy as np
import alexnet
network = alexnet.Alexnet()
network.load_data(sample_fraction=0.1)
network.create_generator(batch_size=32)
network.build_model()
#network.train(dataset_iterations=5)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# Loading input dataset
# A fraction of 0.1 was selected from the total data
# Number of examples in the Train dataset is 120000 and in the Validation dataset is 15000
# Creating the generators
# WARNING:tensorflow:From /home/gpachitariu/git/ml-practice/AlexNet/alexnet.py:101: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.
# WARNING:tensorflow:From /home/gpachitariu/git/ml-practice/AlexNet/alexnet.py:101: The name tf.keras.initializers.RandomNormal is deprecated. Please use tf.compat.v1.keras.initializers.RandomNormal instead.

# %%
import utils
utils.display_images_with_predictions(network.train_augmented_gen, network)
